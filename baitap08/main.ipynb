# %%
# !g++ tomau_dothi.cpp -o tomau_dothi
# !./tomau_dothi
# Out:
# 3
# 1 3 6
# 2 4 7 8 9
# 5

# %% [markdown]
# BAI 2

# %%
# !g++ tomau_dothi_thamlam_cosapxep.cpp -o tomau_dothi_thamlam_cosapxep
# !./tomau_dothi_thamlam_cosapxep
# Out:
# 3
# 2 4 7 8 9
# 1 3 6
# 5

# %% [markdown]
# Bai 2

# %%
# !g++ tomau_toiuu.cpp -o tomau_toiuu
# !./tomau_toiuu
# Out:
# 3
